# %%
# 구글드라이브 마운트
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import io
import pandas as pd

from google.colab import files

uploaded = files.upload()
filename=''
for fn in uploaded.keys():
  print('User uploaded file "{name}" with {length} bytes'.format(name=fn, length=len(uploaded[fn])))
  filename=fn
da=pd.read_csv(io.StringIO(uploaded[filename].decode('utf-8')))
print(da)

# %%
import tensorflow as tf
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt


data = np.loadtxt('/content/gdrive/My Drive/Colab_data/training.csv', delimiter=',', skiprows=1, unpack=True, dtype=np.float32)


x_data = np.transpose(data[0:5])
y_data = np.transpose(data[5:])

# 모델 정의
model = Sequential()
model.add(Dense(input_dim=4, units=10, activation='relu'))
model.add(Dense(units=20, activation='relu'))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=5, activation='relu'))

# 3개의 출력 유닛을 가진 소프트맥스 층을 추가
model.add(Dense(units=3, activation='softmax'))

print("=====================initial weights====================")
for weight in model.weights:
  print(weight)

model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01)
,loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
history = model.fit(x_data, y_data, epochs=100, batch_size=1)

print("=====================weights============================")
for weight in model.weights:
  print(weight)

print("=====================test results=========================")
print(x_data)
# 모델 사용해서 결과 예측해보기
print(model.predict(x_data))
# 모델 사용해서 테스트 데이터로 성능 평가하기 (loss[0]와 Accuracy[1])
print("\n Accuracy: %.4f" % (model.evaluate(x_data, y_data)[1])) # list index

print("==========================================================")

plt.figure(figsize=(12,4))
plt.subplot(1,1,1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['accuracy'], 'g-', label='Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# 체크포인트

import tensorflow as tf
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import pandas as pd

data = np.loadtxt('/content/gdrive/My Drive/Colab_data/Iris-training.csv', delimiter=',', skiprows=1, unpack=True, dtype=np.float32)


x_data = np.transpose(data[0:2])
y_data = np.transpose(data[2:])

# 모델 정의
model = Sequential()
model.add(Dense(input_dim=2, units=10, activation='relu'))
model.add(Dense(units=5, activation='relu'))

# N개의 출력 유닛을 가진 소프트맥스 층을 추가
model.add(Dense(units=2, activation='softmax'))

model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01)
,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

print("=====================initial weights====================")
for weight in model.weights:
  print(weight)


# 체크포인트 경로 설정
checkpoint_path = "/content/gdrive/My Drive/Colab_data/cp.ckpt"
# 체크포인트 콜백 만들기, 체크포인트 파일 경로, (중간) 가중치 저장여부
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, save_weights_only=True, verbose=1)

# 학습 단계에 콜백을 전달
history = model.fit(x_data, y_data, epochs=100, batch_size=1, callbacks = [cp_callback])



print("=====================weights============================")
for weight in model.weights:
  print(weight)

print("=====================test results=========================")
print(x_data)
# 모델 사용해서 결과 예측해보기
print(model.predict(x_data))
# 모델 사용해서 테스트 데이터로 성능 평가하기 (loss[0]와 Accuracy[1])
print("\n Accuracy: %.4f" % (model.evaluate(x_data, y_data)[1])) # list index

print("==========================================================")

plt.figure(figsize=(12,4))
plt.subplot(1,1,1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['accuracy'], 'g-', label='Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# 체크포인트 불러오기

import tensorflow as tf
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import pandas as pd

data = np.loadtxt('/content/gdrive/My Drive/Colab_data/Iris-training.csv', delimiter=',', skiprows=1, unpack=True, dtype=np.float32)

x_data = np.transpose(data[0:2])
y_data = np.transpose(data[2:])

# 모델 정의
model = Sequential()
model.add(Dense(input_dim=2, units=10, activation='relu'))
model.add(Dense(units=5, activation='relu'))

# N개의 출력 유닛을 가진 소프트맥스 층을 추가
model.add(Dense(units=2, activation='softmax'))

print("=====================initial weights====================")
for weight in model.weights:
  print(weight)


model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01)
,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

print("=====================initial weights====================")
for weight in model.weights:
  print(weight)


# 체크포인트 경로 설정
checkpoint_path = "/content/gdrive/My Drive/Colab_data/cp.ckpt"
# 모델 가중치 로드
model.load_weights(checkpoint_path)
# 로드된 가중치로 테스트
loss, acc = model.evaluate(x_data, y_data, verbose=2)
print("훈련된 모델의 정확도: {:5.2f}%".format(100*acc))



print("=====================weights============================")
for weight in model.weights:
  print(weight)

print("=====================test results=========================")
print(x_data)
# 모델 사용해서 결과 예측해보기
print(model.predict(x_data))
# 모델 사용해서 테스트 데이터로 성능 평가하기 (loss[0]와 Accuracy[1])
print("\n Accuracy: %.4f" % (model.evaluate(x_data, y_data)[1])) # list index

print("==========================================================")

plt.figure(figsize=(12,4))
plt.subplot(1,1,1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['accuracy'], 'g-', label='Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# 케라스에서 전체 모델을 h5파일로 저장하기

import tensorflow as tf
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import pandas as pd

data = np.loadtxt('/content/gdrive/My Drive/Colab_data/Iris-training.csv', delimiter=',', skiprows=1, unpack=True, dtype=np.float32)

x_data = np.transpose(data[0:2])
y_data = np.transpose(data[2:])

# 모델 정의
model = Sequential()
model.add(Dense(input_dim=2, units=10, activation='relu'))
model.add(Dense(units=5, activation='relu'))

# N개의 출력 유닛을 가진 소프트맥스 층을 추가
model.add(Dense(units=2, activation='softmax'))

print("=====================initial weights====================")
for weight in model.weights:
  print(weight)


model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01)
,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()


history = model.fit(x_data, y_data, epochs=100, batch_size=1, callbacks = [cp_callback])

# 전체 모델을 HDF5 파일로 저장합니다
model.save("/content/gdrive/My Drive/Colab_data/my_model.h5")



print("=====================weights============================")
for weight in model.weights:
  print(weight)

print("=====================test results=========================")
print(x_data)
# 모델 사용해서 결과 예측해보기
print(model.predict(x_data))
# 모델 사용해서 테스트 데이터로 성능 평가하기 (loss[0]와 Accuracy[1])
print("\n Accuracy: %.4f" % (model.evaluate(x_data, y_data)[1])) # list index

print("==========================================================")

# %%
# HDF5 파일로 모델 불러오고 테스

import tensorflow as tf
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow import keras

data = np.loadtxt('/content/gdrive/My Drive/Colab_data/Iris-training.csv', delimiter=',', skiprows=1, unpack=True, dtype=np.float32)

x_data = np.transpose(data[0:2])
y_data = np.transpose(data[2:])

# 모델 정의
model = Sequential()
model.add(Dense(input_dim=2, units=10, activation='relu'))
model.add(Dense(units=5, activation='relu'))

# N개의 출력 유닛을 가진 소프트맥스 층을 추가
model.add(Dense(units=2, activation='softmax'))

print("=====================initial weights====================")
for weight in model.weights:
  print(weight)



new_model = keras.models.load_model("/content/gdrive/My Drive/Colab_data/my_model.h5")
new_model.summary()
loss, acc = new_model.evaluate(x_data, y_data, verbose=2)
print("복원된 모델의 정확도: {:5.2f}%".format(100*acc))

# %%
# 텐서플로우 Lite로 경량화 시키기
# h5 파일을 tflite 파일로 변환하기

import tensorflow as tf
import numpy as np
import os
from keras.models import Sequential
from keras.layers import Dense
from tensorflow import keras

data = np.loadtxt('/content/gdrive/My Drive/Colab_data/data.csv', delimiter=',', skiprows=1, unpack=True, dtype=np.float32)
x_data = np.transpose(data[0:2])
y_data = np.transpose(data[2:])


model = keras.models.load_model("/content/gdrive/My Drive/Colab_data/my_model.h5", compile=False)
saved_model_path = "/content/gdrive/My Drive/Colab_data/my_model.pb"
model.save(saved_model_path, save_format="tf")
converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_path)
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,tf.lite.OpsSet.SELECT_TF_OPS]
tflite_model = converter.convert()
with open("/content/gdrive/My Drive/Colab Notebooks/model.tflite", 'wb') as f:
  f.write(tflite_model)

# %%
import tensorflow as tf
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt



# training.csv 불러오기
data = np.loadtxt('/content/gdrive/My Drive/Colab_data/test.csv', delimiter=',', skiprows=1, unpack=True, dtype=np.float32)

# 슬라이싱
x_data = np.transpose(data[1:5])
y_data = np.transpose(data[5:])

# 모델 정의
model = Sequential()
model.add(Dense(input_dim=4, units=10, activation='tanh'))
model.add(Dense(units=20, activation='tanh'))
model.add(Dense(units=10, activation='tanh'))
model.add(Dense(units=5, activation='tanh'))

# 3개의 출력 유닛을 가진 소프트맥스 층을 추가
model.add(Dense(units=3, activation='softmax'))

# Adam 최적화
model.compile(optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.001)
,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

history = model.fit(x_data, y_data, epochs=100, batch_size=10, callbacks = [cp_callback])

# 전체 모델을 HDF5 파일로 저장합니다
model.save("/content/gdrive/My Drive/Colab_data/my_model.h5")
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_106 (Dense)           (None, 10)                50
#
#  dense_107 (Dense)           (None, 20)                220
#
#  dense_108 (Dense)           (None, 10)                210
#
#  dense_109 (Dense)           (None, 5)                 55
#
#  dense_110 (Dense)           (None, 3)                 18
#
# ...
# Total params: 553 (2.16 KB)
# Trainable params: 553 (2.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.3016 - accuracy: 0.3000
# Epoch 1: saving model to /content/gdrive/My Drive/Colab_data/cp.ckpt
# 3/3 [==============================] - 0s 71ms/step - loss: 1.2468 - accuracy: 0.3333
# Epoch 2/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0481 - accuracy: 0.5000
# ...

# %%
import tensorflow as tf
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow import keras

data = np.loadtxt('/content/gdrive/My Drive/Colab_data/test.csv', delimiter=',', skiprows=1, unpack=True, dtype=np.float32)

x_data = np.transpose(data[1:5])
y_data = np.transpose(data[5:])

new_model = keras.models.load_model("/content/gdrive/My Drive/Colab_data/my_model.h5")
new_model.summary()

# 테스트 데이터를 읽어와 복원된 모델의 정확도를 표현
loss, acc = new_model.evaluate(x_data, y_data, verbose=2)
print("복원된 모델의 정확도: {:5.2f}%".format(100*acc))


# Training process를 loss와 accuracy graph로 표현
print("==========================================================")

plt.figure(figsize=(12,4))
plt.subplot(1,1,1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['accuracy'], 'g-', label='Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_106 (Dense)           (None, 10)                50
#
#  dense_107 (Dense)           (None, 20)                220
#
#  dense_108 (Dense)           (None, 10)                210
#
#  dense_109 (Dense)           (None, 5)                 55
#
#  dense_110 (Dense)           (None, 3)                 18
#
# ...
# Total params: 553 (2.16 KB)
# Trainable params: 553 (2.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-56-28814d05af87> in <cell line: 18>()
#      16
# ...

# %%
import tensorflow as tf
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import pandas as pd

da = pd.read_csv('C:/test.csv',delimiter=',',skiprows=1,dtype=np.float32)
# da는 pandas 파일이므로 numpy()로 변환, 그리고 데이터 슬라이싱을 위해 transpose 시킨다.
da.to_numpy()
data=np.transpose(da)


# 슬라이싱
x_data = np.transpose(data[1:5])
y_data = np.transpose(data[5:])


# h5를 다시 호출해서 테스트 데이터 세트에 대해 적용
new_model = keras.models.load_model("/content/gdrive/My Drive/Colab_data/my_model.h5")
new_model.summary()

# 테스트 데이터를 읽어와 복원된 모델의 정확도를 표현
loss, acc = new_model.evaluate(x_data, y_data, verbose=2)
print("복원된 모델의 정확도: {:5.2f}%".format(100*acc))
